# %%
# Example of a function that adds 1 to the input
def add(input_value):
    result_value = input_value + 1
    print(input_value, "if you add one", result_value)
    return result_value

# Example of a function that multiplies two numbers
def multiply(input_value, second_input):
    result_value = input_value * second_input
    return result_value

# Example of a function that squares the input and adds 1
def square(input_value):
    local_var = 1
    result_value = input_value * input_value + local_var
    print(input_value, "if you square + 1", result_value)
    return result_value

# Example of a function that concatenates two strings
def concatenate(input_value, second_input):
    return input_value + second_input

# Example of a function that checks the type of album
def type_of_album(artist, album, year_released):
    print(artist, album, year_released)
    if year_released > 1980:
        return "Modern"
    else:
        return "Oldie"

# Example of a function that prints all elements in a list
def print_list(the_list):
    for element in the_list:
        print(element)

# Example of a function with a default argument
def is_good_rating(rating=4):
    if rating < 7:
        print("This album sucks, its rating is", rating)
    else:
        print("This album is good, its rating is", rating)

# Example of a global variable
favorite_artist = "Michael Jackson"

def printer(artist):
    global global_var
    global_var = "Whitney Houston"
    print(artist, "is an artist")

# Example of a function that uses a global variable
def get_band_rating(band_name):
    if band_name == favorite_band:
        return 10.0
    else:
        return 0.0

# Example of a function that accepts multiple arguments
def print_all(*arguments):
    print("Number of arguments:", len(arguments))
    for argument in arguments:
        print(argument)

# Example of a function that accepts keyword arguments
def print_dictionary(**arguments):
    for key in arguments:
        print(key + " : " + arguments[key])

# Example of a function that modifies a list
def add_items(item_list):
    item_list.append("Three")
    item_list.append("Four")

# Example of a function that divides two numbers
def divide(input_value, second_input):
    return input_value / second_input

# Example of using the concatenate function
print(concatenate("This ", "is"))
print(concatenate(2, 2))
print(concatenate(['list', 1], ['tuple', 1]))
# Out:
# This is
# 4
# ['list', 1, 'tuple', 1]
