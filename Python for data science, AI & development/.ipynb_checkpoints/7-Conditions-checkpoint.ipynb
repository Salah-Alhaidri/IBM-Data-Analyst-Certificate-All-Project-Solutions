# %%
# Example of equality comparison
ali_number = 5
print("ali_number == 6:", ali_number == 6)

# Example of greater-than comparison
saeed_number = 6
print("saeed_number > 5:", saeed_number > 5)

saeed_number = 2
print("saeed_number > 5:", saeed_number > 5)

# Example of inequality comparison
saeed_number = 2
print("saeed_number != 6:", saeed_number != 6)

saeed_number = 6
print("saeed_number != 6:", saeed_number != 6)

# Example of string comparison
print("\"ACDC\" == \"Ali Saeed\":", "ACDC" == "Ali Saeed")
print("\"ACDC\" != \"Ali Saeed\":", "ACDC" != "Ali Saeed")

# Example of character comparison
print("'B' > 'A':", 'B' > 'A')
print("'BA' > 'AB':", 'BA' > 'AB')

# Example of if statement
nacer_age = 19
if nacer_age > 18:
    print("You can enter")
print("Move on")

# Example of else statement
nacer_age = 18
if nacer_age > 18:
    print("You can enter")
else:
    print("Go see Meat Loaf")
print("Move on")

# Example of elif statement
nacer_age = 18
if nacer_age > 18:
    print("You can enter")
elif nacer_age == 18:
    print("Go see Pink Floyd")
else:
    print("Go see Meat Loaf")
print("Move on")

# Example of logical operators
mohammad_release_year = 1980
if (mohammad_release_year > 1979) and (mohammad_release_year < 1990):
    print("Album year was in between 1980 and 1989")
print("Do Stuff..")

mohammad_release_year = 1990
if (mohammad_release_year < 1980) or (mohammad_release_year > 1989):
    print("Album was not made in the 1980's")
else:
    print("The Album was made in the 1980's")

mohammad_release_year = 1983
if not (mohammad_release_year == 1984):
    print("Album year is not 1984")

# Quiz on Conditions
ali_rating = 8.5
if ali_rating > 8:
    print("This album is Amazing!")

ali_rating = 8.5
if ali_rating > 8:
    print("This album is Amazing!")
else:
    print("This album is ok")

quiz_release_year = 1980
if quiz_release_year < 1980 or quiz_release_year == 1991 or quiz_release_year == 1993:
    print("This album came out in", quiz_release_year)
# Out:
# ali_number == 6: False
# saeed_number > 5: True
# saeed_number > 5: False
# saeed_number != 6: True
# saeed_number != 6: False
# "ACDC" == "Ali Saeed": False
# "ACDC" != "Ali Saeed": True
# 'B' > 'A': True
# 'BA' > 'AB': True
# You can enter
# Move on
# Go see Meat Loaf
# Move on
# Go see Pink Floyd
# Move on
# Album year was in between 1980 and 1989
# Do Stuff..
# Album was not made in the 1980's
# Album year is not 1984
# This album is Amazing!
# This album is Amazing!
